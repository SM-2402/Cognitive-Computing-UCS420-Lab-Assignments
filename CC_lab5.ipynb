# %% [markdown]
# <a href="https://colab.research.google.com/github/SM-2402/Cognitive-Computing-UCS420-Lab-Assignments/blob/main/CC_lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cognitive Computing Lab Assignment 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])
arr
# Out:
# array([10, 20, 30, 40, 50])

# %% [markdown]
# a) Addition of 2 in all the element

# %%
result1 = arr + 2
result1
# Out:
# array([12, 22, 32, 42, 52])

# %% [markdown]
# b) Multiply 3 with all the elements

# %%
result2 = arr * 3
result2
# Out:
# array([ 30,  60,  90, 120, 150])

# %% [markdown]
# c) Divide every element by 2

# %%
result3 = arr / 2
result3
# Out:
# array([ 5., 10., 15., 20., 25.])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a) Reverse the NumPy array: arr = np.array([1, 2, 3, 6, 4, 5])

# %%
arr2 = np.array([1, 2, 3, 6, 4, 5])
reverse_arr = arr2[::-1]
arr2
# Out:
# array([1, 2, 3, 6, 4, 5])

# %% [markdown]
# b) Find the most frequent value and their indice(s) in the following arrays:

# %% [markdown]
# i. x = np.array([1,2,3,4,5,1,2,1,1,1])

# %%
x = np.array([1, 2, 3, 4, 5, 1, 2, 1, 1, 1])
values, counts = np.unique(x, return_counts=True)
most_frequent_x = values[np.argmax(counts)]
indices_x = np.where(x == most_frequent_x)[0]
most_frequent_x,indices_x
# Out:
# (np.int64(1), array([0, 5, 7, 8, 9]))

# %% [markdown]
# ii. y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3, ])

# %%
y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3, 1])
values, counts = np.unique(y, return_counts=True)
most_frequent_y = values[np.argmax(counts)]
indices_y = np.where(y == most_frequent_y)[0]
most_frequent_y,indices_y
# Out:
# (np.int64(1), array([ 0,  1,  2, 10]))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
arr3 = np.array([[10, 20, 30],[40, 50, 60],[70, 80, 90]])

# %% [markdown]
# a) Access 1st row, 2nd column

# %%
arr3[0][1]
# Out:
# np.int64(20)

# %% [markdown]
# b) Access 3rd row, 1st column

# %%
arr3[2][0]
# Out:
# np.int64(70)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Shashank_Mishra = np.linspace(10, 100, 25)
Shashank_Mishra
# Out:
# array([ 10.  ,  13.75,  17.5 ,  21.25,  25.  ,  28.75,  32.5 ,  36.25,
#         40.  ,  43.75,  47.5 ,  51.25,  55.  ,  58.75,  62.5 ,  66.25,
#         70.  ,  73.75,  77.5 ,  81.25,  85.  ,  88.75,  92.5 ,  96.25,
#        100.  ])

# %%
print("Dimensions:", Shashank_Mishra.ndim)
print("Shape:", Shashank_Mishra.shape)
print("Total elements:", Shashank_Mishra.size)
print("Data type:", Shashank_Mishra.dtype)
print("Total bytes:", Shashank_Mishra.nbytes)
# Out:
# Dimensions: 1
# Shape: (25,)
# Total elements: 25
# Data type: float64
# Total bytes: 200

# %%
Shashank_Mishra_2D = Shashank_Mishra.reshape(1, 25)
transpose = Shashank_Mishra_2D.T
transpose
# Out:
# array([[ 10.  ],
#        [ 13.75],
#        [ 17.5 ],
#        [ 21.25],
#        [ 25.  ],
#        [ 28.75],
#        [ 32.5 ],
#        [ 36.25],
#        [ 40.  ],
#        [ 43.75],
#        [ 47.5 ],
#        [ 51.25],
#        [ 55.  ],
#        [ 58.75],
#        [ 62.5 ],
#        [ 66.25],
#        [ 70.  ],
#        [ 73.75],
#        [ 77.5 ],
#        [ 81.25],
#        [ 85.  ],
#        [ 88.75],
#        [ 92.5 ],
#        [ 96.25],
#        [100.  ]])

# %%
transpose2 = Shashank_Mishra.T
transpose2
# Out:
# array([ 10.  ,  13.75,  17.5 ,  21.25,  25.  ,  28.75,  32.5 ,  36.25,
#         40.  ,  43.75,  47.5 ,  51.25,  55.  ,  58.75,  62.5 ,  66.25,
#         70.  ,  73.75,  77.5 ,  81.25,  85.  ,  88.75,  92.5 ,  96.25,
#        100.  ])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ucs420_Shashank_Mishra = np.array([
    [10, 20, 30, 40],
    [50, 60, 70, 80],
    [90, 15, 20, 35]
])
ucs420_Shashank_Mishra
# Out:
# array([[10, 20, 30, 40],
#        [50, 60, 70, 80],
#        [90, 15, 20, 35]])

# %%
np.mean(ucs420_Shashank_Mishra)
# Out:
# np.float64(43.333333333333336)

# %%
np.median(ucs420_Shashank_Mishra)
# Out:
# np.float64(37.5)

# %%
np.max(ucs420_Shashank_Mishra), np.min(ucs420_Shashank_Mishra)
# Out:
# (np.int64(90), np.int64(10))

# %%
np.unique(ucs420_Shashank_Mishra)
# Out:
# array([10, 15, 20, 30, 35, 40, 50, 60, 70, 80, 90])

# %%
reshaped_ucs420_Shashank_Mishra = ucs420_Shashank_Mishra.reshape(4, 3)
reshaped_ucs420_Shashank_Mishra
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90],
#        [15, 20, 35]])

# %%
resized_ucs420_Shashank_Mishra = np.resize(ucs420_Shashank_Mishra, (2, 3))
resized_ucs420_Shashank_Mishra
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])
