# %% [markdown]
# <a href="https://colab.research.google.com/github/SM-2402/Cognitive-Computing-UCS420-Lab-Assignments/blob/main/CC_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab Assignment 2

# %% [markdown]
# Question 1
# Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L (10
# numbers in list now).

# %% [markdown]
# i. Print L

# %%
L = [10,0,20,40,10,70,0,0,30,30]
for i in range(len(L)):
  print(L[i])
# Out:
# 10
# 0
# 20
# 40
# 10
# 70
# 0
# 0
# 30
# 30

# %% [markdown]
# ii. Add two numbers of your choice to L — one using append() and one using insert() at a specific position.
# Print L after each and explain in a comment what changed.

# %%
L.append(24)
L
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 30, 30, 24]

# %%
L.insert(3,56)
L
# Out:
# [10, 0, 20, 56, 40, 10, 70, 0, 0, 30, 30, 24]

# %% [markdown]
# iii. Remove two elements from L — one using remove() and one using pop(). Print L after each.

# %%
L.pop()
L
# Out:
# [10, 0, 20, 56, 40, 10, 70, 0, 0, 30, 30]

# %%
L.remove(56)
L
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 30, 30]

# %% [markdown]
# iv. Sort L in ascending order using sort(), then descending order using sort(reverse=True). Print both.

# %%
L.sort()
L
# Out:
# [0, 0, 0, 10, 10, 20, 30, 30, 40, 70]

# %%
L.sort(reverse=True)
L
# Out:
# [70, 40, 30, 30, 20, 10, 10, 0, 0, 0]

# %% [markdown]
# v. Use slicing to print the first three elements and the last three elements of L in a single line each.

# %%
n = len(L)
L[0:3],L[n:n-4:-1]
# Out:
# ([70, 40, 30], [0, 0, 0])

# %% [markdown]
# vi. Use list comprehension to create a new list containing only the elements of L that are greater than the
# average of L.

# %%
newList = []
for i in range(len(L)):
  if(L[i]> (sum(L)/len(L))):
    newList.append(L[i])

newList
# Out:
# [70, 40, 30, 30]

# %% [markdown]
# Question 2 Create a tuple named scores containing 8 marks: use the first 8 values from your list L in Q1.

# %%
L2 = [10,0,20,40,10,70,0,0,30,30]
t = tuple(L2[:8])
t
# Out:
# (10, 0, 20, 40, 10, 70, 0, 0)

# %% [markdown]
# i. Find the highest score and its index in the tuple, and the lowest score and how many times it appears.

# %%
x = max(t)
x,t.index(x),t.count(x)
# Out:
# (70, 5, 1)

# %%
y = min(t)
y,t.index(y),t.count(y)
# Out:
# (0, 1, 3)

# %% [markdown]
# ii. Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place —
# explain why in a one-line comment, referring to tuple immutability).

# %%
revt = list(t[::-1])
revt
# Out:
# [0, 0, 70, 10, 40, 20, 0, 10]

# %% [markdown]
# iii. Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present
# message if not.

# %%
s = int(input("Enter a score: "))
if s in t:
  ind = t.index(s)
  print(ind)
else:
  print("Score not found!")
# Out:
# Enter a score: 46
# Score not found!

# %% [markdown]
# iv. Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error
# Python raises, and explain in one line why this happens and how it differs from a list.

# %%
t[5] = 80 #Fails as tuples are immutable objcts unlike a list
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_783/866288285.py in <cell line: 0>()
# ----> 1 t[5] = 80 #Fails as tuples are immutable objcts unlike a list
#       2 t
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# v. Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a
# single line of unpacking.

# %%
first,second,*rest = t
print(first)
print(second)
print(rest)
# Out:
# 10
# 0
# [20, 40, 10, 70, 0, 0]

# %% [markdown]
# Question 3 Set the random seed to your own roll number using random.seed(your_roll_number) before generating
# your numbers — this keeps your list random-looking but reproducible and unique to you (a different seed
# produces a different list, so this cannot be copied from a classmate).

# %%
import random
random.seed(1024170033)

# %% [markdown]
# i. Generate a list of 100 random numbers between 100 and 900 (inclusive).

# %%
empty_l = []
for i in range(100):
  empty_l.append(random.randrange(100,900))

empty_l
# Out:
# [873,
#  193,
#  356,
#  306,
#  806,
#  535,
#  262,
#  473,
#  567,
#  898,
#  594,
#  292,
#  309,
#  815,
#  686,
#  706,
#  560,
#  687,
#  407,
#  411,
#  237,
#  421,
#  757,
#  210,
#  711,
#  120,
#  154,
#  548,
#  624,
#  594,
#  326,
#  265,
#  319,
#  459,
#  147,
#  702,
#  525,
#  124,
#  726,
#  547,
#  783,
#  443,
#  360,
#  311,
#  352,
#  231,
#  700,
#  481,
#  353,
#  872,
#  242,
#  636,
#  376,
#  643,
#  359,
#  637,
#  648,
#  729,
#  589,
#  685,
#  867,
#  578,
#  187,
#  789,
#  241,
#  177,
#  138,
#  221,
#  469,
#  863,
#  429,
#  267,
#  458,
#  435,
#  392,
#  493,
#  597,
#  249,
#  884,
#  478,
#  355,
#  322,
#  891,
#  524,
#  711,
#  820,
#  657,
#  647,
#  865,
#  794,
#  211,
#  726,
#  319,
#  437,
#  718,
#  498,
#  510,
#  439,
#  386,
#  790]

# %% [markdown]
# ii. Count and print all odd numbers in the list.

# %%
counter = 0
for i in range(len(empty_l)):
  if(empty_l[i]%2!=0):
    print(empty_l[i])
    counter+=1
print(f"The count of odd numbers is: {counter}")
# Out:
# 873
# 193
# 535
# 473
# 567
# 309
# 815
# 687
# 407
# 411
# 237
# 421
# 757
# 711
# 265
# 319
# 459
# 147
# 525
# 547
# 783
# 443
# 311
# 231
# 481
# 353
# 643
# 359
# 637
# 729
# 589
# 685
# 867
# 187
# 789
# 241
# 177
# 221
# 469
# 863
# 429
# 267
# 435
# 493
# 597
# 249
# 355
# 891
# 711
# 657
# 647
# 865
# 211
# 319
# 437
# 439
# The count of odd numbers is: 56

# %% [markdown]
# iii. Count and print all even numbers in the list.

# %%
counter2 = 0
for i in range(len(empty_l)):
  if(empty_l[i]%2==0):
    print(empty_l[i])
    counter2+=1
print(f"The count of even numbers is: {counter2}")
# Out:
# 356
# 306
# 806
# 262
# 898
# 594
# 292
# 686
# 706
# 560
# 210
# 120
# 154
# 548
# 624
# 594
# 326
# 702
# 124
# 726
# 360
# 352
# 700
# 872
# 242
# 636
# 376
# 648
# 578
# 138
# 458
# 392
# 884
# 478
# 322
# 524
# 820
# 794
# 726
# 718
# 498
# 510
# 386
# 790
# The count of even numbers is: 44

# %% [markdown]
# iv. Count and print all prime numbers in the list, and additionally build the actual list of prime numbers
# found using list comprehension.

# %%
primenums = []

for i in range(len(empty_l)):
    isPrime = True
    square_root = int(empty_l[i]**0.5) + 1
    for j in range(2, square_root):
        if (empty_l[i] % j == 0):
            isPrime = False
            break
    if (isPrime):
        primenums.append(empty_l[i])

primenums,len(primenums)
# Out:
# ([193, 421, 757, 547, 443, 311, 353, 643, 359, 241, 863, 647, 211, 439], 14)

# %% [markdown]
# v. Print the number that occurs most frequently in your list, and how many times it occurs.

# %%
count = 0
for i in range(len(empty_l)):
  if(empty_l.count(empty_l[i]) > count):
    count = empty_l.count(empty_l[i])
    mostfreq = empty_l[i]

mostfreq,count
# Out:
# (594, 2)

# %% [markdown]
# Question 4 Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for
# each digit} and set B = {digit × 9 for each digit}. Print both sets.

# %%
rollno = [1,0,2,4,1,7,0,0,3,3]
A = {digit * 7 for digit in rollno}
B = {digit * 9 for digit in rollno}

A,B
# Out:
# ({0, 7, 14, 21, 28, 49}, {0, 9, 18, 27, 36, 63})

# %% [markdown]
# vi. Find the union of A and B — all unique values across both sets.

# %%
union = A.union(B)
union
# Out:
# {0, 7, 9, 14, 18, 21, 27, 28, 36, 49, 63}

# %% [markdown]
# vii. Find the intersection of A and B — values common to both.

# %%
intersection = A.intersection(B)
intersection
# Out:
# {0}

# %% [markdown]
# viii. Find A − B and B − A separately (not combined) using difference(), and explain in one line how this
# differs from symmetric_difference().

# %%
A_minus_B = A.difference(B)
B_minus_A = B.difference(A)

print(f"A - B:{A_minus_B}")
print(f"B - A:{B_minus_A}")

print("difference() gives the elements present in one set but not the other.")
print("symmetric_difference() combines A-B and B-A into one set.")
# Out:
# A - B:{7, 14, 49, 21, 28}
# B - A:{36, 9, 18, 27, 63}
# difference() gives the elements present in one set but not the other.
# symmetric_difference() combines A-B and B-A into one set.

# %% [markdown]
# ix. Find the symmetric difference of A and B.

# %%
symm_diff = A.symmetric_difference(B)
symm_diff
# Out:
# {7, 9, 14, 18, 21, 27, 28, 36, 49, 63}

# %% [markdown]
# x. Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset().

# %%
A.issubset(B),B.issubset(A)
# Out:
# (False, False)

# %% [markdown]
# xi. Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain
# in one line why discard() is safer than remove() when you're not sure the value exists.

# %%
X = int(input("Enter a value to remove from set A: "))

A.discard(X)

print("Set A after removing X:")
print(A)
print("discard() is safer because it does not raise an error if the value does not exist.")
# Out:
# Enter a value to remove from set A: 7
# Set A after removing X:
# {0, 14, 49, 21, 28}
# discard() is safer because it does not raise an error if the value does not exist.

# %% [markdown]
# Question 5. Consider the following dictionary:

# %%
my_dict = {
    "name": "Shashank Mishra",
    "roll_no": "1024170033",
    "branch": "COPC",
    "age": 21,
    "city": "Mukerian"
}

my_dict
# Out:
# {'name': 'Shashank Mishra',
#  'roll_no': '1024170033',
#  'branch': 'COPC',
#  'age': 21,
#  'city': 'Mukerian'}

# %% [markdown]
# i. Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by
# hand — use pop() or dictionary comprehension so the code would work for any dictionary).

# %%
my_dict["location"] = my_dict.pop("city")
my_dict
# Out:
# {'name': 'Shashank Mishra',
#  'roll_no': '1024170033',
#  'branch': 'COPC',
#  'age': 21,
#  'location': 'Mukerian'}

# %% [markdown]
# ii. Add a new key “cgpa” with your CGPA as its value.

# %%
my_dict["cgpa"] = 8.99
my_dict
# Out:
# {'name': 'Shashank Mishra',
#  'roll_no': '1024170033',
#  'branch': 'COPC',
#  'age': 21,
#  'location': 'Mukerian',
#  'cgpa': 8.99}

# %% [markdown]
# iii. Update the value of “age” by increasing it by 1.

# %%
my_dict["age"] += 1
my_dict
# Out:
# {'name': 'Shashank Mishra',
#  'roll_no': '1024170033',
#  'branch': 'COPC',
#  'age': 22,
#  'location': 'Mukerian',
#  'cgpa': 8.99}

# %% [markdown]
# iv. Delete the “branch” key using two different methods in two separate copies of the dictionary: once
# with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what
# does each return?).

# %%
dict_pop = my_dict.copy()

removed_value = dict_pop.pop("branch")

print("Dictionary after using pop():")
print(dict_pop)

print("Removed value:", removed_value)
# Out:
# Dictionary after using pop():
# {'name': 'Shashank Mishra', 'roll_no': '1024170033', 'age': 22, 'location': 'Mukerian', 'cgpa': 8.99}
# Removed value: COPC

# %%
dict_del = my_dict.copy()

del dict_del["branch"]

print("Dictionary after using del:")
print(dict_del)

print("pop() removes a key and returns its value, whereas del only deletes the key-value pair.")
# Out:
# Dictionary after using del:
# {'name': 'Shashank Mishra', 'roll_no': '1024170033', 'age': 22, 'location': 'Mukerian', 'cgpa': 8.99}
# pop() removes a key and returns its value, whereas del only deletes the key-value pair.

# %% [markdown]
# v. Iterate over your dictionary using .items() and print each key-value pair as “key → value”.

# %%
for key, value in my_dict.items():
    print(key, ":", value)
# Out:
# name : Shashank Mishra
# roll_no : 1024170033
# branch : COPC
# age : 22
# location : Mukerian
# cgpa : 8.99

# %% [markdown]
# vi. Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence
# using the in keyword and print a safe fallback message instead of letting the program crash.

# %%
if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("Email does not exist in the dictionary.")
# Out:
# Email does not exist in the dictionary.

# %% [markdown]
# vii. Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details.
# Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win”
# when both dictionaries share a key.

# %%
friend_dict = {
    "name": "Harsh Kochar",
    "roll_no": "1024170032",
    "branch": "COPC",
    "age": 20,
    "city": "Patna"
}
friend_dict
# Out:
# {'name': 'Harsh Kochar',
#  'roll_no': '1024170032',
#  'branch': 'COPC',
#  'age': 20,
#  'city': 'Patna'}

# %%
merged_dict = {**my_dict, **friend_dict}
merged_dict

#When the same key exists in both dictionaries, the value from the later dictionary wins.
#Here, friend_dict values win because friend_dict is written after my_dict.
# Out:
# When the same key exists in both dictionaries, the value from the later dictionary wins.
# Here, friend_dict values win because friend_dict is written after my_dict.

# %% [markdown]
# viii. Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your
# original dictionary where the value is a string.

# %%
string_values = {
    key: value
    for key, value in my_dict.items()
    if isinstance(value, str)
}

print("Key-value pairs where the value is a string:")
string_values
# Out:
# Key-value pairs where the value is a string:
# {'name': 'Shashank Mishra',
#  'roll_no': '1024170033',
#  'branch': 'COPC',
#  'location': 'Mukerian'}
